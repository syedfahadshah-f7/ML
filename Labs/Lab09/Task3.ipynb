# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error
import pandas as pd
import numpy as np

# Load dataset

df = pd.read_csv(r"D:\Sem 5\ML LABS\DataSets\iris.csv")
X = df.drop(columns=['species'])
Y = df['species']

# Encode target labels
y_labeled = pd.get_dummies(Y,drop_first=True)
# le = LabelEncoder()
# y_labeled = le.fit_transform(Y)

# Scale features

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data

xtrain, xtest, ytrain, ytest = train_test_split(X_scaled, y_labeled, test_size=0.2, random_state=42)

# Build MLP model

model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile model

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model

model.fit(xtrain, ytrain, epochs=50, batch_size=8, validation_data=(xtest, ytest))
# Out:
# Epoch 1/50
# d:\Sem 5\ML LABS\.venv\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3500 - loss: 1.1348 - val_accuracy: 0.5000 - val_loss: 1.0759
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4417 - loss: 1.0500 - val_accuracy: 0.5000 - val_loss: 0.9895
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5083 - loss: 0.9795 - val_accuracy: 0.6000 - val_loss: 0.9072
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7250 - loss: 0.9087 - val_accuracy: 0.8333 - val_loss: 0.8322
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.8386 - val_accuracy: 0.8667 - val_loss: 0.7601
# Epoch 6/50
# ...

# %%
# Predict

y_pred = model.predict(xtest)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(ytest,axis=1)
# Evaluate

loss, accuracy = model.evaluate(xtest, ytest)
print(f"Test Accuracy: {accuracy*100:.2f}%")


print("Predicted classes:", y_pred_classes)
print("True classes     :", y_true_classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0711
# Test Accuracy: 100.00%
# Predicted classes: [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
# True classes     : [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
