# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, PowerTransformer, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier,AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv(r'Loan_approval_data_2025.csv')
df
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# 0               692                   5.3             895         10820
# 1               627                   3.5             169         16550
# 2               689                   8.4              17          7852
# 3               692                   9.8            1480         11603
# 4               630                   7.2             209         12424
# ...             ...                   ...             ...           ...
# 49995           570                  16.3            1127          7576
# 49996           672                  12.6            1478          6276
# 49997           719                  10.1              17         10331
# 49998           633                   1.3               5          7779
# 49999           695                  15.0            8332          2655
#
#        defaults_on_file  delinquencies_last_2yrs  derogatory_marks  \
# 0                     0                        0                 0
# 1                     0                        1                 0
# 2                     0                        0                 0
# 3                     0                        1                 0
# 4                     0                        0                 0
# ...                 ...                      ...               ...
# 49995                 0                        0                 0
# 49996                 1                        0                 0
# 49997                 0                        0                 0
# 49998                 0                        0                 1
# 49999                 0                        1                 0
#
#         product_type         loan_intent  loan_amount  interest_rate  \
# 0        Credit Card            Business          600          17.02
# 1      Personal Loan    Home Improvement        53300          14.10
# 2        Credit Card  Debt Consolidation         2100          18.33
# 3        Credit Card            Business         2900          18.74
# 4      Personal Loan           Education        99600          13.92
# ...              ...                 ...          ...            ...
# 49995    Credit Card           Education        42800          21.31
# 49996    Credit Card            Personal         3800          18.07
# 49997    Credit Card            Personal        18000          17.45
# 49998  Personal Loan            Personal         1400          14.71
# 49999  Personal Loan            Personal        41000          12.39
#
#        debt_to_income_ratio  loan_to_income_ratio  payment_to_income_ratio  \
# 0                     0.423                 0.023                    0.008
# 1                     0.384                 1.237                    0.412
# 2                     0.377                 0.101                    0.034
# 3                     0.398                 0.099                    0.033
# 4                     0.195                 1.565                    0.522
# ...                     ...                   ...                      ...
# 49995                 0.192                 1.085                    0.362
# 49996                 0.306                 0.185                    0.062
# 49997                 0.551                 0.960                    0.320
# 49998                 0.451                 0.081                    0.027
# 49999                 0.057                 0.874                    0.291
#
#        loan_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 49995            0
# 49996            0
# 49997            0
# 49998            0
# 49999            1
#
# [50000 rows x 20 columns]

# %%
df.drop(columns = ['customer_id'],inplace = True)

# %%
objcols = df.select_dtypes(include='object').columns
numcols = [col for col in df.columns if col not in objcols]

# %%
print(objcols)
print(numcols)
# Out:
# Index(['occupation_status', 'product_type', 'loan_intent'], dtype='object')
# ['age', 'years_employed', 'annual_income', 'credit_score', 'credit_history_years', 'savings_assets', 'current_debt', 'defaults_on_file', 'delinquencies_last_2yrs', 'derogatory_marks', 'loan_amount', 'interest_rate', 'debt_to_income_ratio', 'loan_to_income_ratio', 'payment_to_income_ratio', 'loan_status']

# %%
for col in objcols:
    print(f"Col: {col} Count: {df[col].unique()}")
# Out:
# Col: occupation_status Count: ['Employed' 'Student' 'Self-Employed']
# Col: product_type Count: ['Credit Card' 'Personal Loan' 'Line of Credit']
# Col: loan_intent Count: ['Business' 'Home Improvement' 'Debt Consolidation' 'Education' 'Personal'
#  'Medical']

# %%
for col in numcols:
    print(f"Col: {col} Count: {df[col].skew()}")
# Out:
# Col: age Count: 0.3358600793243518
# Col: years_employed Count: 1.2936126434825892
# Col: annual_income Count: 1.8878688896751907
# Col: credit_score Count: 0.012996167920064387
# Col: credit_history_years Count: 0.9537551630953544
# Col: savings_assets Count: 12.054945856751614
# Col: current_debt Count: 2.437836894846607
# Col: defaults_on_file Count: 3.9693860954550284
# Col: delinquencies_last_2yrs Count: 1.8169443293741545
# Col: derogatory_marks Count: 3.1175467460373585
# Col: loan_amount Count: 0.9314923184493302
# Col: interest_rate Count: 0.019608003856324267
# Col: debt_to_income_ratio Count: 0.5914931983742732
# Col: loan_to_income_ratio Count: 0.6575265420549187
# Col: payment_to_income_ratio Count: 0.6573849299881692
# Col: loan_status Count: -0.20288185984903798

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = pd.get_dummies(df)

# %%
X = df.drop(columns=['loan_status'])
Y = df['loan_status']

# %%
st = StandardScaler()
X_Scaled = st.fit_transform(X)

# %%
x_train,x_test,y_train,ytest = train_test_split(X_Scaled,Y,test_size=0.2,random_state =42,stratify = Y)

# %%
pca = PCA(n_components =0.80)
xpca_train = pca.fit_transform(x_train)
xpca_test = pca.transform(x_test)

# %%
LR = LogisticRegression()
SVM = SVC()
NB = GaussianNB()
KNN = KNeighborsClassifier()
DT = DecisionTreeClassifier()
ADB = AdaBoostClassifier()
VC = VotingClassifier(estimators = [('lr',LR),('nb',NB),('knn',KNN),('dt',DT)],voting = 'soft')

# %%
LR.fit(xpca_train,y_train)
SVM.fit(xpca_train,y_train)
NB.fit(xpca_train,y_train)
KNN.fit(xpca_train,y_train)
DT.fit(xpca_train,y_train)
ADB.fit(xpca_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
models = {
    "Logistic Regression": LR,
    "SVM": SVM,
    "Naive Bayes": NB,
    "KNN": KNN,
    "Decision Tree": DT,
    "AdaBoost": ADB
}

for name, model in models.items():
      
    # Predict
    y_pred_train = model.predict(xpca_train)
    y_pred_test  = model.predict(xpca_test)
    
    # Accuracy
    train_acc = accuracy_score(y_train, y_pred_train)
    test_acc  = accuracy_score(ytest, y_pred_test)
    
    print("====================================")
    print(f"Model: {name}")
    print(f"Training Accuracy: {train_acc:.4f}")
    print(f"Testing Accuracy : {test_acc:.4f}")
# Out:
# ====================================
# Model: Logistic Regression
# Training Accuracy: 0.8543
# Testing Accuracy : 0.8555
# ====================================
# Model: SVM
# Training Accuracy: 0.8965
# Testing Accuracy : 0.8932
# ====================================
# Model: Naive Bayes
# Training Accuracy: 0.8030
# Testing Accuracy : 0.8018
# ====================================
# Model: KNN
# Training Accuracy: 0.9103
# Testing Accuracy : 0.8633
# ====================================
# Model: Decision Tree
# Training Accuracy: 1.0000
# Testing Accuracy : 0.8171
# ====================================
# Model: AdaBoost
# Training Accuracy: 0.8418
# Testing Accuracy : 0.8373

# %% [markdown]
# <!-- model = Sequential()
# model.add(Dense(units=64, activation = 'relu')) -->

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=xpca_train.shape[1], activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1, activation = 'sigmoid'))
model.compile(loss= 'binary_crossentropy',optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(xpca_train,y_train,epochs=50,batch_size=32,validation_data= (xpca_test,ytest))
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8660 - loss: 0.2974 - val_accuracy: 0.8798 - val_loss: 0.2721
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8809 - loss: 0.2645 - val_accuracy: 0.8846 - val_loss: 0.2650
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8838 - loss: 0.2588 - val_accuracy: 0.8864 - val_loss: 0.2603
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8860 - loss: 0.2542 - val_accuracy: 0.8851 - val_loss: 0.2592
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8876 - loss: 0.2487 - val_accuracy: 0.8879 - val_loss: 0.2571
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8914 - loss: 0.2440 - val_accuracy: 0.8877 - val_loss: 0.2531
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8926 - loss: 0.2407 - val_accuracy: 0.8913 - val_loss: 0.2471
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8928 - loss: 0.2376 - val_accuracy: 0.8933 - val_loss: 0.2451
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8948 - loss: 0.2349 - val_accuracy: 0.8928 - val_loss: 0.2461
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8967 - loss: 0.2326 - val_accuracy: 0.8913 - val_loss: 0.2471
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8965 - loss: 0.2309 - val_accuracy: 0.8874 - val_loss: 0.2533
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8977 - loss: 0.2290 - val_accuracy: 0.8939 - val_loss: 0.2448
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8974 - loss: 0.2273 - val_accuracy: 0.8903 - val_loss: 0.2489
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8986 - loss: 0.2256 - val_accuracy: 0.8922 - val_loss: 0.2489
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9017 - loss: 0.2241 - val_accuracy: 0.8934 - val_loss: 0.2447
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8975 - loss: 0.2233 - val_accuracy: 0.8939 - val_loss: 0.2495
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9024 - loss: 0.2205 - val_accuracy: 0.8919 - val_loss: 0.2515
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9016 - loss: 0.2203 - val_accuracy: 0.8930 - val_loss: 0.2414
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9031 - loss: 0.2187 - val_accuracy: 0.8892 - val_loss: 0.2450
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9017 - loss: 0.2176 - val_accuracy: 0.8951 - val_loss: 0.2438
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9028 - loss: 0.2166 - val_accuracy: 0.8947 - val_loss: 0.2458
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9028 - loss: 0.2155 - val_accuracy: 0.8947 - val_loss: 0.2403
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9042 - loss: 0.2143 - val_accuracy: 0.8953 - val_loss: 0.2403
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9053 - loss: 0.2129 - val_accuracy: 0.8975 - val_loss: 0.2424
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9053 - loss: 0.2124 - val_accuracy: 0.8929 - val_loss: 0.2489
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9052 - loss: 0.2110 - val_accuracy: 0.8924 - val_loss: 0.2524
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9048 - loss: 0.2109 - val_accuracy: 0.8915 - val_loss: 0.2454
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9044 - loss: 0.2100 - val_accuracy: 0.8959 - val_loss: 0.2417
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9062 - loss: 0.2086 - val_accuracy: 0.8948 - val_loss: 0.2469
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9054 - loss: 0.2085 - val_accuracy: 0.8919 - val_loss: 0.2453
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9062 - loss: 0.2081 - val_accuracy: 0.8947 - val_loss: 0.2422
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9076 - loss: 0.2062 - val_accuracy: 0.8917 - val_loss: 0.2542
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9075 - loss: 0.2052 - val_accuracy: 0.8926 - val_loss: 0.2464
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9075 - loss: 0.2053 - val_accuracy: 0.8956 - val_loss: 0.2480
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9087 - loss: 0.2039 - val_accuracy: 0.8935 - val_loss: 0.2508
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9093 - loss: 0.2031 - val_accuracy: 0.8934 - val_loss: 0.2454
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9101 - loss: 0.2022 - val_accuracy: 0.8935 - val_loss: 0.2487
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9088 - loss: 0.2019 - val_accuracy: 0.8948 - val_loss: 0.2436
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9089 - loss: 0.2016 - val_accuracy: 0.8954 - val_loss: 0.2465
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9097 - loss: 0.2004 - val_accuracy: 0.8950 - val_loss: 0.2489
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9110 - loss: 0.1993 - val_accuracy: 0.8937 - val_loss: 0.2476
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9113 - loss: 0.1986 - val_accuracy: 0.8946 - val_loss: 0.2584
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9116 - loss: 0.1986 - val_accuracy: 0.8911 - val_loss: 0.2507
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9115 - loss: 0.1974 - val_accuracy: 0.8921 - val_loss: 0.2547
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9123 - loss: 0.1965 - val_accuracy: 0.8930 - val_loss: 0.2502
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9115 - loss: 0.1967 - val_accuracy: 0.8913 - val_loss: 0.2524
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9129 - loss: 0.1946 - val_accuracy: 0.8940 - val_loss: 0.2524
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9141 - loss: 0.1941 - val_accuracy: 0.8918 - val_loss: 0.2586
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9125 - loss: 0.1937 - val_accuracy: 0.8929 - val_loss: 0.2527
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9125 - loss: 0.1937 - val_accuracy: 0.8914 - val_loss: 0.2572

# %%
# y_pred_train = model.predict(xpca_train)
# y_pred_trclasses = np.argmax(y_pred_train, axis=1)
# y_pred_test  = model.predict(xpca_test)
# y_pred_teclasses = np.argmax(y_pred_test, axis=1)
# train_acc = accuracy_score(y_train, y_pred_trclasses)
# test_acc  = accuracy_score(ytest, y_pred_teclasses)
loss,acc = model.evaluate(xpca_test,ytest)
print("====================================")
print(f"Model: {name}")
print(f"Training Accuracy: {loss:.4f}")
print(f"Testing Accuracy : {acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8914 - loss: 0.2572
# ====================================
# Model: AdaBoost
# Training Accuracy: 0.2572
# Testing Accuracy : 0.8914
